# %%
from Constants import Constants
import Utils
import pandas as pd
import numpy as np
import matplotlib as plt
import json
from sklearn.preprocessing import KBinsDiscretizer, quantile_transform
from sklearn.cluster import AgglomerativeClustering

# %%
def load_static_county_data(file=Constants.static_county_data_output_file):
    try:
        with open(file,'r') as f:
            df = json.load(f)
        return df
    except Exception as e:
        print(e)
#         df = processed_county_demographics()
#         df.loc[:,'features'] = df.geometry.apply(lambda x: mapping(x))
#         return pd.DataFrame(df).drop(['geometry'],axis=1).to_dict(orient='index')
    
def load_census_df(file=Constants.static_county_data_output_file):
    df = pd.DataFrame(load_static_county_data()).T
    df.index.name = 'GEOID'
    df = df.drop(['county_fips','features'],axis=1).reset_index()
    df.GEOID = df.GEOID.astype(int)
    return df

def make_geojson(feature_entry):
    gj = {"type": "Feature", "properties": {}, "geometry": feature_entry}
    return gj

def load_county_border_dict(border_json=Constants.static_county_data_output_file):
    #should give {geoid: <geojson item> for each county}
    try:
        with open(border_json,'r') as f:
            border_dict = json.load(f)
        borders = pd.DataFrame(border_dict).T
        borders.index.name = "GEOID"
        return borders.features.apply(make_geojson).to_dict()
    except Exception as e:
        print(e)
        
def load_aggregate_border_dict(border_json=Constants.aggregated_county_border_output_file):
    #should give {geoid: <geojson item> for each group of countys}
    try:
        with open(border_json,'r') as f:
            aggregate_borders = json.load(f)
        return aggregate_borders
    except Exception as e:
        print(e)
        
class TweetClusterer():
    
    def __init__(self,fields,id_field='case_id', n_clusters=4, quant_bins=30):
        self.fields = fields
        self.bins= quant_bins
        self.id_field=id_field
        self.n_clusters = n_clusters
        self.discretizer = KBinsDiscretizer(quant_bins,encode='ordinal')
        self.clusterer = AgglomerativeClustering(n_clusters,linkage='ward')
        
    def transform(self,x):
        return self.clusterer.fit_predict(x)
    
    def fit_kbins(self,x):
        self.discretizer.fit(x)
        
    def valid_fields(self,field_lists):
        #returns the fields in self.fields that are in a list of lists of columns
        #for figuring out what fields to reguarlize
        to_keep = set(self.fields)
        for field_list in field_lists:
            to_keep = to_keep.intersection(set(field_list))
        return sorted(to_keep)
        
    def transform_df(self,tweet_df, county_df):
        #dataframe should have an id as an index for this to work good with linking in UI
        #will calculate quantiles based on the county
        try:
            #figure out what data is in the demographics so we can regularize it - so we ignore derived stuff
            regularize_fields = self.valid_fields([tweet_df.columns,county_df.columns])
            default_fields = sorted(set(self.fields) - set(regularize_fields))
            print(regularize_fields,default_fields)
            cdata = county_df.loc[:,regularize_fields].values
            self.fit_kbins(cdata)
            
            #regularize fields based on county-level quantiles
            tdf = tweet_df.copy() 
            transform_tdata = tdf.loc[:,regularize_fields].values
            tdf.loc[:,regularize_fields] = self.discretizer.transform(transform_tdata)
            
            #but we are clustering the tweets
            tdata = tweet_df.loc[:,self.fields].values
            tindex = tdf.reset_index().loc[:,self.id_field]
            
            tclusters = self.transform(tdata)
            
            #should be 2 columns: cluster and the class id_field (for merging later)
            cluster_series = pd.DataFrame(tclusters,index=tindex,columns=['cluster'])
            cluster_series = cluster_series.reset_index()
#             self.current_clusters = cluster_series
            return cluster_series
        except Exception as e:
            print('error in transform_df', e)
            
    def add_clusters(self,augmented_tweet_df,county_df):
        cluster_df = self.transform_df(augmented_tweet_df, county_df)
        index = augmented_tweet_df.index.name
        df = augmented_tweet_df.reset_index().merge(cluster_df,on=self.id_field)
        if index is not None:
            df = df.set_index(index)
        return df

class DataProcessor():
    
    def __init__(self, quant_bins = 5):
        self.quant_bins = quant_bins
        self.sentiment_threshold = .25
        self.demographic_df = load_census_df()
        self.demographic_fields = self.get_demographic_fields(self.demographic_df)
        
        self.tweet_df = pd.read_csv(Constants.tweet_output_file)#,dtype={'GEOID':int})
        covid_df = pd.read_csv(Constants.covid_cases_output_file)#,dtype={'GEOID':int})
        self.covid_df = covid_df.drop('Unnamed: 0', axis=1)
        
        self.augmented_tweet_df = self.augment_tweets()
        
        #currently loads in as a dict {id:<geojson string>,...}
        self.county_borders = load_county_border_dict()
        self.aggregate_borders = load_aggregate_border_dict()
        
        self.frames = self.get_frames()
        self.current_tweet_clusters = None
        
    def get_frames(self):
        frames = ['Authority','Betrayal',
                  'Care','Degradation',
                  'Fairness','Freedom',
                  'Harm','Injustice',
                  'Loyalty','Oppression',
                  'Purity','Subversion'
                 ]
        return frames
    
    def get_demographic_fields(self, demographic_df):
        #extract columns that are census/county numerical data
        d_fields = set(demographic_df.columns)
        extra_fields = set(['GEOID','parent','state_fips','county_name'])
        return list(d_fields - extra_fields)
    
    def augment_tweets(self):
        ddf = self.demographic_df.copy() #bin_edges = self.quantize_demographics(self.demographic_df, self.quant_bins) 
        tdf = self.tweet_df.copy()
        cdf = self.covid_df.copy()
        
        ddf_to_drop = list(set(ddf.columns).intersection(set(['county_name','state_fips'])))
        mdf = tdf.merge(ddf.drop(ddf_to_drop,axis=1),on='GEOID',how='left')
        mdf = mdf.merge(cdf,on=['GEOID','day','month','year'],how='left')
        
        mdf.loc[:,'is_blue'] = (mdf.net_dem_president_votes > 0).astype(int)
        mdf.loc[:,'cases_per_capita'] = (mdf.cases/mdf.cvap)
        mdf.loc[:,'deaths_per_capita'] = (mdf.deaths/mdf.cvap)
        return mdf[mdf.GEOID != 0]

    def stratify_retweet_thresholds(self, n_quantiles=5, retweet_col='retweet_count'):
        tdf = self.tweet_df.copy()
        retweets = tdf[tdf[retweet_col] > 1]
        retweets = retweets[retweet_col]
        quantile_edges =np.quantile(retweets,[0,.2,.4,.6,.8,.9],interpolation='nearest')
        quantile_edges = sorted(set([0,1]).union(set(quantile_edges)))
        quantile_edges = [int(q)  for q in quantile_edges]
        return quantile_edges

    def filter_geolocated(self, df):
        return df[df.GEOID != 0].copy().fillna(-1)
    
    def format_frameview_df(self, month=None,year=None):
        #file to get data formated for the moral-frame view.  need to add int sentiment later
        #only geolocated tweets I guess
        tweet_df = self.filter_geolocated(self.augmented_tweet_df)
        #filter by month if needed.  I think I am not planning on doing that tho
        if month is not None:
            tweet_df = tweet_df[(tweet_df.month == int(month))]
        if year is not None:
            tweet_df = tweet_df[(tweet_df.year == int(year))]

        quantile_thresholds = self.stratify_retweet_thresholds(self.tweet_df.copy())
        frame_data = {}

        for frame in self.frames:
            frame_df = tweet_df[tweet_df[frame] > 0]
            entry = {'total_tweets': frame_df.shape[0]}
            for_rt_quantiles = []
            against_rt_quantiles = []
            for idx, q in enumerate(quantile_thresholds):

                tweets_in_quantile = frame_df[frame_df.retweet_count >= q]
                if idx + 1 < len(quantile_thresholds):
                    maxval = quantile_thresholds[idx+1]
                    tweets_in_quantile = tweets_in_quantile[tweets_in_quantile.retweet_count < maxval]

                for_sah_q = (tweets_in_quantile.for_sah > 0).sum()
                against_sah_q = (tweets_in_quantile.for_sah <= 0).sum()

                for_rt_quantiles.append(for_sah_q)
                against_rt_quantiles.append(against_sah_q)
    
            entry['vivid'] = frame_df.is_vivid.sum()
            entry['for_sah'] = frame_df.for_sah.sum()
            entry['is_blue'] = frame_df.is_blue.sum()
            entry['for_sah_rt_quantiles'] = for_rt_quantiles
            entry['against_sah_rt_quantiles'] = against_rt_quantiles
            entry['positive_sentiment'] = (frame_df.sentiment_score > self.sentiment_threshold).sum()
            entry['negative_sentiment'] = (frame_df.sentiment_score < -self.sentiment_threshold).sum()
            #these are for future use maybe.  not efficient but it's like 5 values so i don't care
            entry['quantile_bins'] = quantile_thresholds
            entry['high_retweets'] = (frame_df.retweet_count > 100).sum()
            frame_data[frame] = entry
        return pd.DataFrame(frame_data).T.fillna(-1)
    
    def load_frameview_dict(self,month=None,year=None):
        #loads in the data for using in the view with overview dat afor each frame
        frame_df = self.format_frameview_df(month,year)
        return frame_df.to_dict(orient='index')
    
    def load_timeline_dict(self,frame=None,min_retweets = 0, month=None,year=None):
        #get data to use for the big timeline.  Should be similar to the default format for tweets?
        #should be like: {day: [tweets in day as a json object], day2: [...]}
        df = self.filter_geolocated(self.augmented_tweet_df)
        
        #drop extra features, but check that they're in the columns because there's no good way to do that in pandas?
        to_drop = ['screen_name','user_id'] + self.demographic_fields
        df = df.drop(list(set(df.columns).intersection(set(to_drop))),axis=1)
        print(to_drop, df.columns)
        #filter stuff to the selected month and frame
        if frame is not None:
            df = df[df[frame] == 1]
        if month is not None:
            df = df[df.month == month]
        if year is not None:
            df = df[df.year == year]
        #in case we want only popular tweets
        df = df[df.retweet_count >= min_retweets].drop(['month','year'],axis=1)
        tweet_dict = {day:d.to_dict(orient='records') for day,d in df.groupby('day')}
        return tweet_dict
    
    def aggregate_county_demographics(self,ddf):
        #should return a dataframe with aggreagted demographics and the parent congressional district
        #will only keep the demographic fields for now
        d_fields = self.demographic_fields
        ddf.loc[:,d_fields] = ddf.loc[:,d_fields].astype(float)
        sum_fields = ['cvap','net_dem_gov_votes','net_dem_president_votes','repgov']
        median_fields = ['ruralurban_cc']
        wmean_fields = sorted(set(d_fields) - set(sum_fields) - set(median_fields))
        district_data = {}
        for district, sub_df in ddf.groupby('parent'):
            entry = {}
            medians = sub_df.loc[:,median_fields].median().to_dict()
            sums = sub_df.loc[:,sum_fields].sum().to_dict()
            wmeans = {}
            total_pop = sub_df.cvap.sum()
            for wmf in wmean_fields:
                values = sub_df[wmf]*sub_df.cvap
                entry[wmf] = values.sum()/total_pop
            for val_dict in [medians, sums, wmeans]:
                for k,v in val_dict.items():
                    entry[k] = v
            district_data[district] = entry
        district_df = pd.DataFrame(district_data).T
        district_df.index.name = 'parent'
        return district_df.reset_index()
        
    def format_county_data(self, month=None,year=None,aggregate = False):
        #data for the county map
        tdf = self.filter_geolocated(self.augmented_tweet_df.copy())
        if month is not None:
            tdf = tdf[tdf.month == month]
        if year is not None:
            tdf = tdf[tdf.year == year]
            
        ddf = self.demographic_df.copy()
        #aggregates county census data by the containing congressional ditrict.
        if aggregate:
            ddf = self.aggregate_county_demographics(ddf)
        key = 'GEOID' if aggregate is False else 'parent'
        ddf = ddf.set_index(key)
#         ddf.index = ddf.index.astype(int)
        
        frames = self.get_frames()
        
        data_dict = {}
        for geoid, df in tdf.groupby(key):
#             geoid=int(geoid)
            entry = df.loc[:,frames].sum().to_dict()
            entry['total_tweets'] = df.shape[0]
            #average sentiment weighted be popularity of the tweet
            retweet_weights = (df.retweet_count+2).apply(np.log)
            entry['weighted_sentiment'] = ((retweet_weights*df.sentiment_score).sum())/(retweet_weights.sum())
        
            entry['median_deaths'] = df.loc[:,'deaths'].median()
            entry['median_cases'] = df.loc[:,'cases'].median()
            
            calc_change = lambda key: df.loc[:,key].max() - df.loc[:,key].min()
            entry['cases_change'] = calc_change('cases')
            entry['deaths_change'] = calc_change('deaths')
            demographics = ddf.loc[geoid]
            for dem in self.demographic_fields:
                entry[dem] = demographics[dem]
            data_dict[geoid] = entry
        data = pd.DataFrame(data_dict)
        return data
    
    def load_county_dict(self, month=None,year=None,aggregate=False):
        #issue: I'm not aggregating stuff properly????????
        county_df = self.format_county_data(month,year,aggregate).T
        if aggregate:
            map_json = self.aggregate_borders
        else:
            map_json = self.county_borders
        return county_df.to_dict(orient='index')
    
    def tweets_in_cluster(self,tweet_id):
        #given a tweet id (currently case_id), gives the list of ids with the same cluster
        #for linking in the UI
        cc = self.current_tweet_clusters
        if cc is None:
            return []
        active_cluster = cc.loc[tweet_id].cluster
        active_tweets = cc[cc.cluster == active_cluster]
        return active_tweets.index.to_list()
    
    def get_tweet_clusters(self,cluster_fields,n_clusters,identifier='case_id'):
        clusterer = TweetClusterer(cluster_fields, identifier, n_clusters)
        
        tdf = self.filter_geolocated(self.augmented_tweet_df)
        tdf = tdf.drop(self.get_frames(),axis=1)
        tdf = clusterer.add_clusters(tdf,self.demographic_df)
        self.current_tweet_clusters = tdf.loc[:,[identifier,'cluster']].set_index(identifier)
        if 'index' in tdf.columns:
            return tdf.drop('index',axis=1)
        return tdf

    def bin_tweet_features(self,tweet_df,to_discretize,n_bins=10):
        #stuff to skip because it's ordinal
        x_discrete = tweet_df.loc[:,to_discretize].values
        x_discrete = KBinsDiscretizer(n_bins,encode='ordinal',strategy='quantile').fit_transform(x_discrete)
        tdf = tweet_df.copy()
        tdf.loc[:,to_discretize] = x_discrete.astype('int')
        return tdf
    
    def bin_demographics(self,tweet_df,to_discretize,n_bins=10):
        tdf = tweet_df.copy()
        demographics = [x for x in to_discretize if x in self.demographic_fields]
        discretizer = KBinsDiscretizer(n_bins,encode='ordinal')
        x_fit = self.demographic_df.loc[:,demographics].values
        discretizer.fit(x_fit)
        tdf.loc[:,demographics] = discretizer.transform(tdf.loc[:,demographics].values)
        return tdf,demographics
    
    def decile_count(self,values,n_bins):
        decile_counts = []
        for decile in range(n_bins):
            in_decile = (values.astype(int) == int(decile)).sum()
            decile_counts.append(in_decile)
        return decile_counts
            
    def tweet_cluster_df(self,cluster_fields,n_clusters,n_bins=5):
        #should already filter geolocated here
        tcluster_df = self.get_tweet_clusters(cluster_fields,n_clusters)
        to_discretize = ['deaths_per_capita','cases_per_capita','retweet_count']
        tcluster_df = self.bin_tweet_features(tcluster_df,to_discretize,n_bins)
        
        tcluster_df,binned_fields = self.bin_demographics(tcluster_df,cluster_fields,n_bins)
        
        cluster_dict = {}
        for cluster, subdf in tcluster_df.groupby('cluster'):
            cluster_size = subdf.shape[0]
            entry = {'total_tweets': cluster_size}
            
            for field in binned_fields + ['cases_per_capita','deaths_per_capita']:
                values = subdf.loc[:,field]
                entry[field + '_quantiles'] = self.decile_count(values,n_bins)
                
            for_sah_rt = subdf[subdf.for_sah == 1].loc[:,'retweet_count']
            against_sah_rt = subdf[subdf.for_sah < 1].loc[:,'retweet_count']
            entry['for_sah_rt_quantiles'] = self.decile_count(for_sah_rt,n_bins)
            entry['against_sah_rt_quantiles'] = self.decile_count(against_sah_rt,n_bins)
            
            entry['is_blue'] = subdf.is_blue.sum()
            entry['positive_sentiment'] = (subdf.sentiment_score > self.sentiment_threshold).sum()
            entry['negative_sentiment'] = (subdf.sentiment_score < -self.sentiment_threshold).sum()
            #for use in clustering
            entry['GEOIDs'] = list(np.unique(subdf.GEOID))
            entry['parents'] = list(np.unique(subdf.parent))
            cluster_dict[cluster] = entry
        return pd.DataFrame(cluster_dict).T
    
    def load_tweetcluster_dict(self,cluster_fields,n_clusters,n_bins=5):
        cluster_df = self.tweet_cluster_df(cluster_fields,n_clusters,n_bins)
        return cluster_df.to_dict(orient='records')
        
data = DataProcessor()
# data.load_frameview_dict()
# data.load_timeline_dict()
# data.load_county_dict()
data.load_tweetcluster_dict(['urm_pct','cvap'],4)
# data.get_tweet_clusters(['is_blue','cvap'],4)
# Out:
# ['cvap', 'urm_pct'] []
# /home/evl/andrew/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_discretization.py:193: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 2 are removed. Consider decreasing the number of bins.
#   'decreasing the number of bins.' % jj)
# [{'GEOIDs': [1015,
#    1017,
#    1047,
#    1073,
#    1097,
#    1101,
#    1125,
#    4001,
#    4005,
#    4009,
#    4015,
#    4019,
#    4021,
#    4025,
#    5051,
#    5125,
#    6013,
#    6017,
#    6019,
#    6021,
#    6025,
#    6045,
#    6053,
#    6061,
#    6075,
#    6077,
#    6079,
#    6081,
#    6083,
#    6095,
#    6097,
#    6099,
#    6107,
#    6111,
#    6113,
#    8005,
#    8013,
#    8031,
#    8035,
#    8059,
#    8077,
#    8101,
#    8123,
#    9003,
#    9007,
#    9009,
#    10003,
#    11001,
#    12009,
#    12017,
#    12033,
#    12053,
#    12073,
#    12081,
#    12087,
#    12091,
#    12097,
#    12101,
#    12103,
#    12109,
#    12111,
#    12113,
#    12115,
#    12117,
#    12127,
#    13015,
#    13021,
#    13029,
#    13047,
#    13051,
#    13059,
#    13067,
#    13089,
#    13121,
#    13139,
#    13157,
#    13219,
#    13245,
#    13279,
#    13303,
#    13311,
#    15003,
#    15007,
#    15009,
#    16001,
#    17023,
#    17041,
#    17043,
#    17097,
#    17099,
#    17113,
#    17119,
#    17163,
#    17165,
#    17167,
#    17185,
#    17195,
#    17197,
#    17199,
#    17201,
#    18003,
#    18019,
#    18035,
#    18039,
#    18057,
#    18063,
#    18089,
#    18091,
#    18097,
#    18099,
#    18127,
#    18141,
#    18157,
#    18173,
#    19103,
#    19113,
#    19153,
#    19155,
#    20015,
#    20091,
#    20155,
#    20161,
#    20173,
#    20177,
#    21071,
#    21093,
#    21111,
#    21117,
#    21209,
#    22001,
#    22033,
#    22051,
#    22061,
#    22071,
#    22073,
#    22075,
#    22103,
#    22109,
#    22121,
#    23005,
#    24001,
#    24003,
#    24005,
#    24015,
#    24017,
#    24021,
#    24027,
#    24029,
#    24031,
#    24033,
#    24035,
#    24043,
#    24510,
#    25003,
#    25005,
#    25009,
#    25015,
#    25019,
#    25021,
#    25023,
#    25025,
#    25027,
#    26041,
#    26043,
#    26049,
#    26065,
#    26075,
#    26077,
#    26081,
#    26099,
#    26139,
#    26145,
#    26147,
#    26149,
#    26161,
#    27003,
#    27037,
#    27111,
#    27123,
#    27131,
#    27137,
#    27139,
#    27163,
#    28047,
#    28059,
#    28067,
#    29047,
#    29095,
#    29099,
#    29145,
#    29183,
#    29186,
#    29189,
#    29510,
#    30063,
#    30111,
#    31055,
#    31109,
#    31153,
#    32019,
#    32031,
#    32510,
#    33011,
#    34003,
#    34005,
#    34007,
#    34013,
#    34015,
#    34017,
#    34019,
#    34021,
#    34023,
#    34025,
#    34027,
#    34029,
#    34031,
#    34035,
#    34041,
#    35001,
#    35043,
#    35061,
#    36001,
#    36007,
#    36027,
#    36029,
#    36045,
#    36053,
#    36055,
#    36067,
#    36071,
#    36085,
#    36087,
#    36091,
#    36109,
#    36111,
#    36119,
#    37031,
#    37045,
#    37057,
#    37063,
#    37067,
#    37081,
#    37097,
#    37119,
#    37135,
#    37159,
#    37179,
#    37183,
#    39017,
#    39057,
#    39061,
#    39077,
#    39081,
#    39089,
#    39093,
#    39095,
#    39099,
#    39119,
#    39143,
#    39151,
#    39153,
#    39157,
#    39161,
#    39175,
#    40017,
#    40027,
#    40109,
#    40143,
#    41003,
#    41005,
#    41009,
#    41029,
#    41033,
#    41035,
#    41047,
#    41051,
#    41067,
#    42007,
#    42011,
#    42017,
#    42019,
#    42029,
#    42041,
#    42049,
#    42067,
#    42071,
#    42073,
#    42077,
#    42091,
#    42093,
#    42125,
#    44003,
#    44005,
#    44007,
#    44009,
#    45003,
#    45013,
#    45019,
#    45035,
#    45045,
#    45051,
#    45063,
#    45079,
#    46099,
#    47011,
#    47037,
#    47051,
#    47065,
#    47157,
#    47163,
#    47179,
#    47187,
#    48001,
#    48027,
#    48039,
#    48041,
#    48061,
#    48085,
#    48091,
#    48121,
#    48135,
#    48141,
#    48157,
#    48167,
#    48183,
#    48187,
#    48209,
#    48215,
#    48251,
#    48303,
#    48325,
#    48337,
#    48339,
#    48355,
#    48367,
#    48371,
#    48453,
#    48479,
#    48485,
#    48491,
#    48507,
#    49005,
#    49035,
#    49057,
#    51013,
#    51041,
#    51059,
#    51061,
#    51065,
#    51087,
#    51107,
#    51121,
#    51153,
#    51161,
#    51550,
#    51650,
#    51680,
#    51710,
#    51760,
#    51810,
#    53005,
#    53011,
#    53015,
#    53027,
#    53031,
#    53037,
#    53041,
#    53051,
#    53053,
#    53061,
#    53063,
#    53067,
#    53077,
#    54011,
#    55031,
#    55055,
#    55059,
#    55073,
#    55079,
#    55087,
#    55133,
#    55139],
#   'against_sah_rt_quantiles': [126, 24, 0, 0, 0],
#   'cases_per_capita_quantiles': [194, 200, 170, 158, 119],
#   'cvap_quantiles': [0, 13, 39, 56, 733],
#   'deaths_per_capita_quantiles': [223, 179, 163, 133, 143],
#   'for_sah_rt_quantiles': [530, 161, 0, 0, 0],
#   'is_blue': 478,
#   'negative_sentiment': 312,
#   'parents': ['0101',
#    '0102',
#    '0103',
#    '0104',
#    '0106',
#    '0107',
#    '0401',
#    '0403',
#    '0404',
#    '0502',
#    '0504',
#    '0602',
#    '0603',
#    '0604',
#    '0605',
#    '0609',
#    '0610',
#    '0611',
#    '0612',
#    '0614',
#    '0620',
#    '0621',
#    '0622',
#    '0624',
#    '0626',
#    '0651',
#    '0801',
#    '0802',
#    '0803',
#    '0804',
#    '0806',
#    '0807',
#    '0901',
#    '0903',
#    '1000',
#    '1198',
#    '1201',
#    '1204',
#    '1205',
#    '1206',
#    '1207',
#    '1208',
#    '1209',
#    '1211',
#    '1212',
#    '1213',
#    '1216',
#    '1218',
#    '1226',
#    '1301',
#    '1302',
#    '1304',
#    '1305',
#    '1306',
#    '1309',
#    '1310',
#    '1311',
#    '1312',
#    '1314',
#    '1501',
#    '1502',
#    '1601',
#    '1701',
#    '1708',
#    '1710',
#    '1712',
#    '1713',
#    '1715',
#    '1716',
#    '1717',
#    '1718',
#    '1801',
#    '1802',
#    '1803',
#    '1804',
#    '1805',
#    '1806',
#    '1807',
#    '1808',
#    '1809',
#    '1901',
#    '1902',
#    '1903',
#    '2001',
#    '2002',
#    '2003',
#    '2004',
#    '2102',
#    '2103',
#    '2104',
#    '2105',
#    '2106',
#    '2201',
#    '2202',
#    '2203',
#    '2205',
#    '2206',
#    '2301',
#    '2401',
#    '2403',
#    '2404',
#    '2405',
#    '2406',
#    '2407',
#    '2408',
#    '2501',
#    '2502',
#    '2504',
#    '2506',
#    '2507',
#    '2508',
#    '2509',
#    '2601',
#    '2602',
#    '2603',
#    '2604',
#    '2605',
#    '2606',
#    '2607',
#    '2608',
#    '2609',
#    '2610',
#    '2612',
#    '2702',
#    '2704',
#    '2706',
#    '2707',
#    '2708',
#    '2804',
#    '2901',
#    '2902',
#    '2905',
#    '2906',
#    '2907',
#    '2908',
#    '3000',
#    '3101',
#    '3102',
#    '3202',
#    '3204',
#    '3302',
#    '3401',
#    '3403',
#    '3404',
#    '3405',
#    '3406',
#    '3407',
#    '3408',
#    '3409',
#    '3410',
#    '3411',
#    '3412',
#    '3501',
#    '3502',
#    '3503',
#    '3611',
#    '3616',
#    '3617',
#    '3618',
#    '3619',
#    '3620',
#    '3621',
#    '3622',
#    '3623',
#    '3624',
#    '3625',
#    '3626',
#    '3703',
#    '3704',
#    '3705',
#    '3709',
#    '3710',
#    '3712',
#    '3713',
#    '3901',
#    '3904',
#    '3905',
#    '3906',
#    '3907',
#    '3908',
#    '3909',
#    '3910',
#    '3911',
#    '3912',
#    '3913',
#    '4001',
#    '4003',
#    '4004',
#    '4005',
#    '4101',
#    '4102',
#    '4103',
#    '4104',
#    '4105',
#    '4201',
#    '4204',
#    '4206',
#    '4207',
#    '4209',
#    '4210',
#    '4211',
#    '4212',
#    '4214',
#    '4216',
#    '4217',
#    '4401',
#    '4402',
#    '4501',
#    '4502',
#    '4504',
#    '4507',
#    '4600',
#    '4701',
#    '4703',
#    '4704',
#    '4705',
#    '4707',
#    '4709',
#    '4801',
#    '4803',
#    '4805',
#    '4808',
#    '4811',
#    '4812',
#    '4813',
#    '4814',
#    '4815',
#    '4816',
#    '4817',
#    '4819',
#    '4821',
#    '4822',
#    '4823',
#    '4825',
#    '4826',
#    '4827',
#    '4828',
#    '4831',
#    '4834',
#    '4835',
#    '4901',
#    '4904',
#    '5102',
#    '5103',
#    '5104',
#    '5105',
#    '5106',
#    '5107',
#    '5108',
#    '5109',
#    '5110',
#    '5111',
#    '5301',
#    '5303',
#    '5304',
#    '5305',
#    '5306',
#    '5308',
#    '5310',
#    '5403',
#    '5501',
#    '5504',
#    '5505',
#    '5506',
#    '5507',
#    '5508'],
#   'positive_sentiment': 355,
#   'total_tweets': 841,
#   'urm_pct_quantiles': [11, 47, 180, 316, 287]},
#  {'GEOIDs': [6001,
#    6065,
#    6067,
#    6071,
#    6085,
#    12011,
#    12057,
#    12086,
#    12095,
#    12099,
#    25017,
#    26125,
#    26163,
#    27053,
#    32003,
#    36005,
#    36047,
#    36059,
#    36061,
#    36081,
#    36103,
#    39035,
#    39049,
#    42003,
#    42101,
#    48029,
#    48113,
#    48439,
#    53033],
#   'against_sah_rt_quantiles': [42, 6, 0, 0, 0],
#   'cases_per_capita_quantiles': [60, 55, 77, 79, 108],
#   'cvap_quantiles': [0, 0, 0, 0, 379],
#   'deaths_per_capita_quantiles': [44, 64, 83, 80, 108],
#   'for_sah_rt_quantiles': [265, 66, 0, 0, 0],
#   'is_blue': 358,
#   'negative_sentiment': 130,
#   'parents': ['0607',
#    '0615',
#    '0619',
#    '0631',
#    '0636',
#    '1210',
#    '1214',
#    '1221',
#    '1223',
#    '1227',
#    '2505',
#    '2611',
#    '2613',
#    '2705',
#    '3201',
#    '3601',
#    '3604',
#    '3606',
#    '3609',
#    '3613',
#    '3615',
#    '3903',
#    '3911',
#    '4202',
#    '4218',
#    '4820',
#    '4830',
#    '4833',
#    '5307'],
#   'positive_sentiment': 179,
#   'total_tweets': 379,
#   'urm_pct_quantiles': [0, 0, 17, 85, 277]},
#  {'GEOIDs': [4013, 6059, 6073, 17031, 48201],
#   'against_sah_rt_quantiles': [19, 2, 0, 0, 0],
#   'cases_per_capita_quantiles': [23, 33, 27, 37, 37],
#   'cvap_quantiles': [0, 0, 0, 0, 157],
#   'deaths_per_capita_quantiles': [19, 37, 33, 57, 11],
#   'for_sah_rt_quantiles': [105, 31, 0, 0, 0],
#   'is_blue': 119,
#   'negative_sentiment': 60,
#   'parents': ['0406', '0646', '0652', '1707', '4829'],
#   'positive_sentiment': 67,
#   'total_tweets': 157,
#   'urm_pct_quantiles': [0, 0, 0, 0, 157]},
#  {'GEOIDs': [6037],
#   'against_sah_rt_quantiles': [14, 1, 0, 0, 0],
#   'cases_per_capita_quantiles': [20, 8, 23, 22, 33],
#   'cvap_quantiles': [0, 0, 0, 0, 106],
#   'deaths_per_capita_quantiles': [11, 16, 18, 26, 35],
#   'for_sah_rt_quantiles': [62, 29, 0, 0, 0],
#   'is_blue': 106,
#   'negative_sentiment': 41,
#   'parents': ['0640'],
#   'positive_sentiment': 47,
#   'total_tweets': 106,
#   'urm_pct_quantiles': [0, 0, 0, 0, 106]}]

# %%
data.load_timeline_dict()
# Out:
# ['screen_name', 'user_id', 'cvap', 'net_dem_gov_votes', 'demgov', 'repgov', 'female_pct', 'net_dem_president_votes', 'mask_score', 'urm_pct', 'median_hh_inc', 'ruralurban_cc', 'clf_unemploy_pct', 'lesshs_pct', 'lesscollege_pct'] Index(['case_id', 'Authority', 'Betrayal', 'Care', 'Degradation', 'Fairness',
#        'Freedom', 'GEOID', 'Harm', 'Injustice', 'Loyalty', 'Oppression',
#        'Purity', 'Subversion', 'for_sah', 'is_vivid', 'retweet_count', 'text',
#        'month', 'day', 'year', 'sentiment_score', 'parent', 'deaths', 'cases',
#        'is_blue', 'cases_per_capita', 'deaths_per_capita'],
#       dtype='object')
# {1: [{'case_id': 1082,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 8031,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 2.0,
#    'text': 'Stay Home - Save Lives https://t.co/S80v6pcr1H',
#    'day': 1,
#    'sentiment_score': 0.4939,
#    'parent': '0801',
#    'deaths': 8.0,
#    'cases': 586.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0012673695593403622,
#    'deaths_per_capita': 1.7301973506353068e-05},
#   {'case_id': 1086,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6085,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 2.0,
#    'text': '660 died in 24 hours IN THE UNITED STATES. And yall still wanna be goin outside hanging w friends. STAY YA ASS HOME',
#    'day': 1,
#    'sentiment_score': -0.29600000000000004,
#    'parent': '0619',
#    'deaths': 32.0,
#    'cases': 956.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0008368896767557394,
#    'deaths_per_capita': 2.801304357341387e-05},
#   {'case_id': 1090,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 15007,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@LynnKawano May God continue to watch over him and bless him with more healing. Please also watch over his family and friends who are also experiencing a stressful time. In Jesus Name, Amen. \n\nStay safe, stay home, and stay strong!! ',
#    'day': 1,
#    'sentiment_score': 0.9195,
#    'parent': '1502',
#    'deaths': 0.0,
#    'cases': 12.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0002402161945751176,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1096,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 22051,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 1,
#    'retweet_count': 1.0,
#    'text': 'One of my coworkers is in the hospital.\nOn a ventilator. At 33.\n\nMy round. My fuckin dawg. I really cant believe this. \n\nThis coronavirus shit is for real man. Stay safe, stay home and sanitize.',
#    'day': 1,
#    'sentiment_score': -0.1779,
#    'parent': '2202',
#    'deaths': 64.0,
#    'cases': 1433.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0045941266991536295,
#    'deaths_per_capita': 0.000205180815593742},
#   {'case_id': 1097,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Do your part and stay home',
#    'day': 1,
#    'sentiment_score': 0.0,
#    'parent': '0640',
#    'deaths': 64.0,
#    'cases': 3518.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0005745089809895991,
#    'deaths_per_capita': 1.045155622039066e-05},
#   {'case_id': 1102,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24005,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'its going to take more than a few people for us to get through this... EVERYONE needs to care! Stay patient, stay healthy &amp; STAY HOME!  @DulaneyHigh @DulaneyLibrary @dulaneyyearbook @DulaneyPTSA @CoachLochte @CoachKorrow @mikmellis #StayHome #dulaney2020 https://t.co/pfY5ItlbtM',
#    'day': 1,
#    'sentiment_score': 0.7568,
#    'parent': '2407',
#    'deaths': 1.0,
#    'cases': 289.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0004774018765693141,
#    'deaths_per_capita': 1.6519096075062773e-06},
#   {'case_id': 1107,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6059,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 1,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 0,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@VBTheWise We are in prison we have to stay home.',
#    'day': 1,
#    'sentiment_score': -0.5106,
#    'parent': '0646',
#    'deaths': 10.0,
#    'cases': 606.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00030493097540173147,
#    'deaths_per_capita': 5.031864280556625e-06},
#   {'case_id': 1109,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6019,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Im just convinced that we all gonna die anyways SINCE EVERYBODY AND THEY MOMMAS DONT KNOW HOW TO STAY THE FUCK HOME AND STOP HANGING OUT WITH THEIR FRIENDS. ',
#    'day': 1,
#    'sentiment_score': -0.6739,
#    'parent': '0621',
#    'deaths': 0.0,
#    'cases': 68.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00012010739013706372,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1110,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6077,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 1.0,
#    'text': 'Governors who refuse to demand to have stay at home orders are effecting all of us. These will kill many Americans because their just stupid.',
#    'day': 1,
#    'sentiment_score': -0.8957,
#    'parent': '0609',
#    'deaths': 8.0,
#    'cases': 151.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00034849236663243285,
#    'deaths_per_capita': 1.846317174211565e-05},
#   {'case_id': 1113,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24015,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'WE are the solution. Stay at home. Only go out if you really need to. Do NOT cross state lines. Act as if your life, or the life of a loved one, depends on your behavior. Because it does. WE are the solution.',
#    'day': 1,
#    'sentiment_score': 0.8176,
#    'parent': '2401',
#    'deaths': 0.0,
#    'cases': 16.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00020880913539967374,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1128,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 36055,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 1,
#    'retweet_count': 0.0,
#    'text': 'About frickin time... @GovRonDeSantis\n\nMy grandmother lives down in Florida and your delay in doing this risks her life. Cant wait to see you voted out of office ASAP!\n\n Florida Gov. Ron DeSantis issues stay-at-home order following mounting pressure  https://t.co/B6wvIJAtUa',
#    'day': 1,
#    'sentiment_score': -0.7325,
#    'parent': '3625',
#    'deaths': 9.0,
#    'cases': 349.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0006189095487635109,
#    'deaths_per_capita': 1.596041816295587e-05},
#   {'case_id': 1129,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 26161,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "Look who ISN'T practicing social distancing!  You don't want to be like these spider mites. Stay Home, Stay Safe, and stay six feet away from one another! \n.\n\n.\n#socialdistancing #covid19 #knowledgeispower https://t.co/LWE1JfU4Nn",
#    'day': 1,
#    'sentiment_score': 0.6968,
#    'parent': '2612',
#    'deaths': 8.0,
#    'cases': 430.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0016173317786888329,
#    'deaths_per_capita': 3.0089893557001543e-05},
#   {'case_id': 1141,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 45045,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@wyffnews4 - Can you please call the governor and ask him point blank why SC is the ONLY state (along with Alabama) east of the Mississippi that has NOT mandated stay-at-home orders. Please...we need to stay (get) ahead of the novel coronavirus. Thank you!',
#    'day': 1,
#    'sentiment_score': 0.75,
#    'parent': '4504',
#    'deaths': 1.0,
#    'cases': 129.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.000371672236948254,
#    'deaths_per_capita': 2.881180131381814e-06},
#   {'case_id': 1143,
#    'Authority': 1,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 26043,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@psehunter71 @PGDougSchneider Should not be coming here period. No rationalization for it at all. Listen to instructions. Stay home.',
#    'day': 1,
#    'sentiment_score': -0.29600000000000004,
#    'parent': '2601',
#    'deaths': 0.0,
#    'cases': 0.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1146,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 16001,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 4.0,
#    'text': 'I just feel like its really not hard to stay home right now. Are people really that ignorant that it takes a loved one being affected to take this seriously...? Like how many more deaths is it going to take TO JUST STAY HOME',
#    'day': 1,
#    'sentiment_score': 0.6829,
#    'parent': '1601',
#    'deaths': 3.0,
#    'cases': 195.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0006349929987951415,
#    'deaths_per_capita': 9.769123058386791e-06},
#   {'case_id': 2279,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 1,
#    'GEOID': 6073,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@PatrickRuffini That doesn't mean a thing... but stay home I'f you want . Its you're decision",
#    'day': 1,
#    'sentiment_score': 0.1154,
#    'parent': '0652',
#    'deaths': 124.0,
#    'cases': 3564.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0016390954621338595,
#    'deaths_per_capita': 5.7028012711727995e-05},
#   {'case_id': 2282,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 42101,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 2.0,
#    'text': 'Though we may be physically separated, #TeamPennsylvania will get through this pandemic together.\n\nStay vigilant, stay strong and #StayHome. https://t.co/qDtZHM7B9c',
#    'day': 1,
#    'sentiment_score': 0.6124,
#    'parent': '4202',
#    'deaths': 638.0,
#    'cases': 15137.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.013511197593566181,
#    'deaths_per_capita': 0.0005694750653825212},
#   {'case_id': 2286,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 1,
#    'Freedom': 0,
#    'GEOID': 41047,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'People that are going to the beach are the reason we are on lockdown until June 30th. Stop being so fucking selfish.',
#    'day': 1,
#    'sentiment_score': -0.7070000000000001,
#    'parent': '4105',
#    'deaths': 18.0,
#    'cases': 508.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0023437139561707037,
#    'deaths_per_capita': 8.304498269896193e-05},
#   {'case_id': 2289,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 4013,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@TomthunkitsMind So stay home, stay safe save lives that mitigated spread of virus had nothing to do w a lower mortality? We'll all pay dearly when Trump &amp; Republican governors open their states' businesses etc too early.\n#LifeOverProfit",
#    'day': 1,
#    'sentiment_score': 0.743,
#    'parent': '0406',
#    'deaths': 147.0,
#    'cases': 4156.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.001525941183705915,
#    'deaths_per_capita': 5.397337680576744e-05},
#   {'case_id': 2290,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24029,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '#TruthBeTold \nAbso-fucking-lutly!!! \n#Disgusting  to live in #trumpsamerica this isnt #winning!!!\n\nTump is #willfullyIGNORANT #conman #coronavirus #COVID19 forever #TrumpVirus #Blametrump 4 every death!!!\n        \n#COVIDIOTS#PhysicalDistancing #StayHome #StayHomeSaveLives https://t.co/sAmMQJUYBm',
#    'day': 1,
#    'sentiment_score': -0.7243,
#    'parent': '2401',
#    'deaths': 4.0,
#    'cases': 86.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.005419029615626969,
#    'deaths_per_capita': 0.0002520478890989288},
#   {'case_id': 2291,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 39161,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 1,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 0,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@realDonaldTrump the people of Ohio are imprisoned. Allowing this could cost you votes. We're done. Sr. Citizens still very alive made to stay home. No social outlets. Many are alone.  Get crackin. PLEASE !!",
#    'day': 1,
#    'sentiment_score': -0.2163,
#    'parent': '3905',
#    'deaths': 0.0,
#    'cases': 3.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00013885674612358251,
#    'deaths_per_capita': 0.0},
#   {'case_id': 2294,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12099,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 1.0,
#    'text': 'God bless her, the baby and your family. Many prayers for u tonite.  Stay well.\nEveryone else...stay the hell home...its n o t safe out there. Are u trusting them a 2nd time?  No way not me. I need proof now...no more covid!!!! https://t.co/6qvmeUzMvE',
#    'day': 1,
#    'sentiment_score': 0.7156,
#    'parent': '1221',
#    'deaths': 191.0,
#    'cases': 3041.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0031205586425929062,
#    'deaths_per_capita': 0.0001959969420372394},
#   {'case_id': 2296,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 147.0,
#    'text': 'Most deaths in a day. Stay at home order lifted. \n\nThese two things should not exist in the same headline. \n\nAnd definitely not in the same state. https://t.co/YfvgMYG1XU',
#    'day': 1,
#    'sentiment_score': 0.4019,
#    'parent': '0640',
#    'deaths': 1174.0,
#    'cases': 24262.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.003962119640923721,
#    'deaths_per_capita': 0.00019172073441779116},
#   {'case_id': 2298,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24029,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Abso-fucking-lutly!!! \n#Heartbreaking to live in #trumpsamerica #winning\n\nTump is #willfullyIGNORANT #coronavirus #COVID19 is forever #TrumpVirus #Blametrump 4 every death!!!\n        \n#COVIDIOTS #WeDontHaveDays2Waste #StayHome #StayHomeSaveLives #StayHomeStayHealthy https://t.co/VaCWMXVlYm',
#    'day': 1,
#    'sentiment_score': -0.7243,
#    'parent': '2401',
#    'deaths': 4.0,
#    'cases': 86.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.005419029615626969,
#    'deaths_per_capita': 0.0002520478890989288},
#   {'case_id': 2299,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24029,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Abso-fucking-lutly!!! \n#Heartbreaking to live in #trumpsamerica #winning\n\nTump is #willfullyIGNORANT #coronavirus #COVID19 is forever #TrumpVirus #Blametrump 4 every death!!!\n        \n#COVIDIOTS #WeDontHaveDays2Waste #StayHome #StayHomeSaveLives #StayHomeStayHealthy https://t.co/DkaBYHDI6S',
#    'day': 1,
#    'sentiment_score': -0.7243,
#    'parent': '2401',
#    'deaths': 4.0,
#    'cases': 86.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.005419029615626969,
#    'deaths_per_capita': 0.0002520478890989288},
#   {'case_id': 2300,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 1,
#    'Freedom': 0,
#    'GEOID': 12086,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@TedJasper1 @thehill We have to stay home why not him.',
#    'day': 1,
#    'sentiment_score': 0.0,
#    'parent': '1227',
#    'deaths': 358.0,
#    'cases': 12389.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.007985046969916695,
#    'deaths_per_capita': 0.00023074072283720855},
#   {'case_id': 2302,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 39095,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 1,
#    'retweet_count': 0.0,
#    'text': 'NIGGGGGGA I JUST LOST ANOTHER FAMILY MEMBER TO COVID-19 AND TWO OTHER RELATIVES HAVE IT! PLEASE STAY TF HOME MAN DAMN !!!!!!!!!!!!!!!!!!!',
#    'day': 1,
#    'sentiment_score': -0.6809,
#    'parent': '3909',
#    'deaths': 119.0,
#    'cases': 1297.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.003961999022482893,
#    'deaths_per_capita': 0.000363514173998045},
#   {'case_id': 2304,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 26163,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 1,
#    'retweet_count': 0.0,
#    'text': '@jokachmartin @NiccoQuinto @pskiffington @fred_guttenberg @GovWhitmer Not the issue, Healthcare rights. This virus is unpredictable. To fight it Stay  home Stay safe. If you do not want to do that and you  take a risk and jeopardize your health, your Family, others &amp; my sister. Then no Health Care for the Protesters.',
#    'day': 1,
#    'sentiment_score': -0.775,
#    'parent': '2613',
#    'deaths': 1906.0,
#    'cases': 17235.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.013451444849856588,
#    'deaths_per_capita': 0.001487580730132095},
#   {'case_id': 2305,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 26163,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@thehill Yall stupid ass mfs wanna die so bad! Stay yall goofy asses at home! Its a reason we should be in the house! Just Ask all the dead people!',
#    'day': 1,
#    'sentiment_score': -0.9711,
#    'parent': '2613',
#    'deaths': 1906.0,
#    'cases': 17235.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.013451444849856588,
#    'deaths_per_capita': 0.001487580730132095},
#   {'case_id': 2306,
#    'Authority': 1,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 25009,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'I feel that states should not rush to reopen the country. It pains me to see citizens not taking government orders seriously. This virus is unpredictable and opening some states only puts the American people at risk for infection. #coronavirus #COVID #COVID__19 #StayHome #America',
#    'day': 1,
#    'sentiment_score': -0.6808,
#    'parent': '2506',
#    'deaths': 460.0,
#    'cases': 9870.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.017966687903886412,
#    'deaths_per_capita': 0.0008373532356421226},
#   {'case_id': 2308,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 45079,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "Public places may reopen, but you don't have to go there. STAY HOME and practice social distancing when you have to leave. Others may opt to risk contracting COVID-19, but not me. Be smart and be well!",
#    'day': 1,
#    'sentiment_score': -0.5391,
#    'parent': '4502',
#    'deaths': 34.0,
#    'cases': 913.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0030150421874742006,
#    'deaths_per_capita': 0.00011227977477998118},
#   {'case_id': 2313,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12081,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Armed protestors storming Michigans capital over stay at home restrictions ? Insurrection at its extreme . Life saving orders to bring down mortality rates are being flaunted . Trumps words to his followers are going to be the ruination of our democracy and nation .',
#    'day': 1,
#    'sentiment_score': -0.5719,
#    'parent': '1216',
#    'deaths': 57.0,
#    'cases': 591.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0022578365265228935,
#    'deaths_per_capita': 0.00021776088326870547},
#   {'case_id': 2314,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6019,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Please stay home. We all want to enjoy our summer. Lets all do our part. Also, stream the #SaySoRMX for clear skin. https://t.co/IUHuVOiIvH',
#    'day': 1,
#    'sentiment_score': 0.8126,
#    'parent': '0621',
#    'deaths': 8.0,
#    'cases': 615.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.001086265366680797,
#    'deaths_per_capita': 1.4130281192595733e-05},
#   {'case_id': 2317,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 25021,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 0,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '#MichiganTerrorists #MichiganProtest \n#MichigandersAgainstExcessiveQuarantine \n#Michigan over 41,000 #coronavirus cases with over 3,700 deaths. another 3000 die ....ppl think  good idea to stay at home  maybe more deaths will change their minds! Life is cheap in America',
#    'day': 1,
#    'sentiment_score': -0.3164,
#    'parent': '2508',
#    'deaths': 522.0,
#    'cases': 6409.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.012840084946107305,
#    'deaths_per_capita': 0.0010457987738910926},
#   {'case_id': 2319,
#    'Authority': 1,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 39049,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Literally says STAY AT HOME, man what in the fuck are you doing?!?!?!?! https://t.co/c86KBugpTa https://t.co/aaUc2jBdrF',
#    'day': 1,
#    'sentiment_score': -0.7669,
#    'parent': '3903',
#    'deaths': 76.0,
#    'cases': 2589.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.002947253385243242,
#    'deaths_per_capita': 8.651651497817166e-05},
#   {'case_id': 2326,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12095,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'If you live in one of these states that are going to start to open (like Florida), please stay home.  Let the idiots rush back to their versions of "normal" so they can spike the infection rates back up and then we can shut down all over again and for a much longer time...',
#    'day': 1,
#    'sentiment_score': 0.5859,
#    'parent': '1210',
#    'deaths': 34.0,
#    'cases': 1413.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0016533954282972835,
#    'deaths_per_capita': 3.9784461827393945e-05},
#   {'case_id': 2330,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 8035,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@JoshuaPotash @tschet No small irony too that state stay at home orders are to protect lives -esp those of the medically vulnerable. Exact opposite of Nazi Germany.',
#    'day': 1,
#    'sentiment_score': -0.0905,
#    'parent': '0806',
#    'deaths': 23.0,
#    'cases': 502.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0023203679308511868,
#    'deaths_per_capita': 0.00010631167810672768},
#   {'case_id': 2332,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 48157,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'as soon as we opened our doors, like 20 people rushed in our store. you people are fucking selfish. STAY AT HOME',
#    'day': 1,
#    'sentiment_score': -0.2247,
#    'parent': '4822',
#    'deaths': 26.0,
#    'cases': 1052.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0025143703916155787,
#    'deaths_per_capita': 6.214223401331277e-05},
#   {'case_id': 3762,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'stay home and safe.  https://t.co/51IijkDLnN',
#    'day': 1,
#    'sentiment_score': 0.4404,
#    'parent': '0640',
#    'deaths': 2386.0,
#    'cases': 56011.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.009146908054067206,
#    'deaths_per_capita': 0.0003896470803414393},
#   {'case_id': 3784,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12103,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Covid-19 is still a reality! Continue to Stay Safe, Stay Home, and Stay Prayerful! @ Saint Petersburg, Florida https://t.co/2CI38EgjYV',
#    'day': 1,
#    'sentiment_score': 0.5399,
#    'parent': '1213',
#    'deaths': 83.0,
#    'cases': 1313.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0017806649352762878,
#    'deaths_per_capita': 0.00011256297762980342},
#   {'case_id': 3798,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 53067,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': ' What did you do with Covid-19?  https://t.co/TG7EhQPT1c?  ... Socially, politically, economically, stay home orders, etc. #Stayhomestaysafe #StayHomeSaveLives #COVID19Pakistan #COVID19SouthAfrica #coronavirus #CoronaVirusUpdate #CoronaWarriors #covid_19 #NOW #NowPlaying',
#    'day': 1,
#    'sentiment_score': 0.0,
#    'parent': '5310',
#    'deaths': 1.0,
#    'cases': 155.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0007756787188790192,
#    'deaths_per_capita': 5.004378831477543e-06},
#   {'case_id': 3799,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@lsmrnnbttd Stay home and stay safe.',
#    'day': 1,
#    'sentiment_score': 0.4404,
#    'parent': '0640',
#    'deaths': 2386.0,
#    'cases': 56011.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.009146908054067206,
#    'deaths_per_capita': 0.0003896470803414393},
#   {'case_id': 3800,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 26099,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@tylergabriel_ Stay home stay safe',
#    'day': 1,
#    'sentiment_score': 0.4404,
#    'parent': '2609',
#    'deaths': 851.0,
#    'cases': 6855.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.010709096873974786,
#    'deaths_per_capita': 0.0013294589992345065},
#   {'case_id': 3808,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6085,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Anyway, stay safe and inside. Theres still a whole global pandemic outside',
#    'day': 1,
#    'sentiment_score': 0.4404,
#    'parent': '0619',
#    'deaths': 141.0,
#    'cases': 2776.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0024301315299936534,
#    'deaths_per_capita': 0.00012343247324535486}],
#  2: [{'case_id': 1148,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 36005,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@nycgov Nicely spoken because why anyone is going to the Emergency room if they don't have a Emergency. It doesn't make any sense. So please stay safe and stay home alone. God bless America our home sweet home. ",
#    'day': 2,
#    'sentiment_score': 0.9265,
#    'parent': '3615',
#    'deaths': 655.0,
#    'cases': 11463.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.013801780758417665,
#    'deaths_per_capita': 0.0007886387853758677},
#   {'case_id': 1150,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 1,
#    'Freedom': 0,
#    'GEOID': 17031,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 1,
#    'retweet_count': 0.0,
#    'text': "WTF Lori! I thought you said stay home and save lives! You better take yo' ass back home before I make a citizen's arrest!\n.\n.\n.\n#whereslightfoot #lorilightfoot #stayhomesavelives #quarantine #flattenthecurve #covid19 #drmemes #memeology #memeologist https://t.co/IVce1Oj0DG",
#    'day': 2,
#    'sentiment_score': -0.7359,
#    'parent': '1707',
#    'deaths': 107.0,
#    'cases': 5575.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0015877197354275095,
#    'deaths_per_capita': 3.0472827209101977e-05},
#   {'case_id': 1151,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 48029,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@sweetk01 Dannnng that sucks! Hopefully soon it goes back to normal. If everyone can stay home and not get sick! ',
#    'day': 2,
#    'sentiment_score': 0.5402,
#    'parent': '4820',
#    'deaths': 9.0,
#    'cases': 229.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00018528857279251725,
#    'deaths_per_capita': 7.28208364686749e-06},
#   {'case_id': 1152,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12091,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@BamaGoose256 If your worried about getting it, stay home.....its simple',
#    'day': 2,
#    'sentiment_score': -0.29600000000000004,
#    'parent': '1201',
#    'deaths': 1.0,
#    'cases': 51.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00034637326813365934,
#    'deaths_per_capita': 6.791632708503124e-06},
#   {'case_id': 1158,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Stay home, save lives https://t.co/JYNapeN4Ty',
#    'day': 2,
#    'sentiment_score': 0.4939,
#    'parent': '0640',
#    'deaths': 78.0,
#    'cases': 4045.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0006605710142418784,
#    'deaths_per_capita': 1.2737834143601116e-05},
#   {'case_id': 1159,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 4021,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 1.0,
#    'text': 'SECOND WAVE ... STAY TF HOME https://t.co/iHoVTOqHTY',
#    'day': 2,
#    'sentiment_score': 0.0,
#    'parent': '0401',
#    'deaths': 0.0,
#    'cases': 69.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0002480051757601898,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1163,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 34021,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'We are not super heroes #StayHome #StopTheSpead #SaveLives https://t.co/EAlEeBADQW',
#    'day': 2,
#    'sentiment_score': -0.7048,
#    'parent': '3412',
#    'deaths': 4.0,
#    'cases': 386.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0015412873342916468,
#    'deaths_per_capita': 1.5971889474524837e-05},
#   {'case_id': 1176,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 47065,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@R2andDan @lang @AndyBerke @GovBillLee I agree with you big picture. \n\nJust don't see this as an encroachment. People have to stay home to keep everyone safe. \n\nPeople right to be a dumbass and go out ends when it starts endangering my life.",
#    'day': 2,
#    'sentiment_score': 0.2023,
#    'parent': '4703',
#    'deaths': 5.0,
#    'cases': 61.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.000227781926811053,
#    'deaths_per_capita': 1.8670649738610905e-05},
#   {'case_id': 1181,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 34007,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'That figures!  Shows which states have idiots as Governirs. People in these states should self quarantine.  Save yourselves please. https://t.co/AQkWFbv6wI',
#    'day': 2,
#    'sentiment_score': 0.6996,
#    'parent': '3401',
#    'deaths': 6.0,
#    'cases': 343.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0009287213159141677,
#    'deaths_per_capita': 1.6245853922696813e-05},
#   {'case_id': 1182,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 20091,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@GovParsonMO a little late on your "stay at home" order.\n300+ a day in new cases is \nall due to your ignorance. \nGrateful that @GovLauraKelly was looking out for Kansas.\n\nLive blog: MO reports 1,800 COVID-19 cases, 19 deaths - https://t.co/6wYzV8FF2n',
#    'day': 2,
#    'sentiment_score': 0.128,
#    'parent': '2003',
#    'deaths': 3.0,
#    'cases': 161.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00039832751923600285,
#    'deaths_per_capita': 7.422251911229867e-06},
#   {'case_id': 1183,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6065,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'I do not understand why people are still traveling  this is why the #COVID19 curve isnt flattening! STAY. THE. FUCK. HOME.',
#    'day': 2,
#    'sentiment_score': -0.6731,
#    'parent': '0636',
#    'deaths': 14.0,
#    'cases': 493.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0003392384681284427,
#    'deaths_per_capita': 9.63354676226815e-06},
#   {'case_id': 1187,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 44007,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@CaddieChris814 It makes sense. Stay home, be safe.',
#    'day': 2,
#    'sentiment_score': 0.4404,
#    'parent': '4401',
#    'deaths': 10.0,
#    'cases': 418.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0009391253552612364,
#    'deaths_per_capita': 2.2467113762230535e-05},
#   {'case_id': 2339,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 48113,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 3.0,
#    'text': 'Not 1, not 2... 3!!! SMU is the move! Stay home, get a great education and be a #NeighborhoodHero. Whos next? #TripleD21 #PonyUpDallas https://t.co/dhZhyBSfxQ',
#    'day': 2,
#    'sentiment_score': 0.7405,
#    'parent': '4830',
#    'deaths': 134.0,
#    'cases': 3899.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.002686399542505951,
#    'deaths_per_capita': 9.232560623128942e-05},
#   {'case_id': 2341,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 36005,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@NYPDnews Nicely done offerser. We most keep our distance and stay home and save lives. God bless America our home sweet home ',
#    'day': 2,
#    'sentiment_score': 0.9186,
#    'parent': '3615',
#    'deaths': 3188.0,
#    'cases': 39904.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0480455604452498,
#    'deaths_per_capita': 0.0038384434317225435},
#   {'case_id': 2343,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12057,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@VitoRebecca1 @AshaniTW @arjunrajlab Hopefully very soon! Glad to hear that you and your family are doing well. Stay safe, stay home',
#    'day': 2,
#    'sentiment_score': 0.8826,
#    'parent': '1214',
#    'deaths': 24.0,
#    'cases': 1240.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0013536970120413532,
#    'deaths_per_capita': 2.6200587329832643e-05},
#   {'case_id': 2345,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 55133,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 1,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 0,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'You must end all the Governors martial law attempts to dictate to the American people! Stay-at-Home orders must stop! We are losing our God given Freedoms! https://t.co/AOkbR40bDT',
#    'day': 2,
#    'sentiment_score': -0.3348,
#    'parent': '5505',
#    'deaths': 22.0,
#    'cases': 356.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00119163179916318,
#    'deaths_per_capita': 7.364016736401674e-05},
#   {'case_id': 2346,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 5051,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'I want them to stay home IF THEY GET SICK! https://t.co/yQdOpCvE7q',
#    'day': 2,
#    'sentiment_score': -0.6155,
#    'parent': '0504',
#    'deaths': 0.0,
#    'cases': 117.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0015554373836745546,
#    'deaths_per_capita': 0.0},
#   {'case_id': 2350,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 1,
#    'GEOID': 31153,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 1,
#    'Subversion': 0,
#    'for_sah': 0,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'God                                           No\nFreedom                                 Fear\nCountry\n                            \n                  OpEn AmErIcA https://t.co/Yq6P3v2TBr https://t.co/jPcGkelQYb',
#    'day': 2,
#    'sentiment_score': 0.0926,
#    'parent': '3102',
#    'deaths': 0.0,
#    'cases': 137.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0011441934271516265,
#    'deaths_per_capita': 0.0},
#   {'case_id': 2357,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6061,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@realDonaldTrump  another  famous  death on your hands  Stay At Home https://t.co/Ycq0OqRq8r',
#    'day': 2,
#    'sentiment_score': -0.5994,
#    'parent': '0604',
#    'deaths': 8.0,
#    'cases': 159.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.000586207532213763,
#    'deaths_per_capita': 2.9494718601950337e-05},
#   {'case_id': 2358,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Were in this together #AloneTogether #LosAngeles #fashion #stayhome @ Los Angeles, California https://t.co/yyLIqm7G8r',
#    'day': 2,
#    'sentiment_score': 0.0,
#    'parent': '0640',
#    'deaths': 1209.0,
#    'cases': 24894.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0040653287586000795,
#    'deaths_per_capita': 0.0001974364292258173},
#   {'case_id': 2362,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 1,
#    'GEOID': 6037,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 0,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@ChargersUnion You realize that an awful economy will be worse for this country as a whole than the few thousand people that will die of this disease, dont put everyone on lock down, have those who are vulnerable stay home and quarantine. It should be our choice',
#    'day': 2,
#    'sentiment_score': -0.8979,
#    'parent': '0640',
#    'deaths': 1209.0,
#    'cases': 24894.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0040653287586000795,
#    'deaths_per_capita': 0.0001974364292258173},
#   {'case_id': 2364,
#    'Authority': 1,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 9009,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@JoshuaPotash I cannot believe they're protesting because they can't go to the beach! Awful!\nWhy can the rest of the world comply (for the most part) with stay at home orders...but we do this????\nUnbelievable",
#    'day': 2,
#    'sentiment_score': 0.4359,
#    'parent': '0903',
#    'deaths': 565.0,
#    'cases': 8024.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.012701930459146926,
#    'deaths_per_capita': 0.00089439066667722},
#   {'case_id': 2365,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 39089,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'The ABSOLUTE disrespect to those who suffered great tragedies at Auschwitz is appalling. Saying you should stay home is nothing like what the people in death camps had to go through. Im ashamed of how our population is acting in response to those trying to keep them safe. https://t.co/S8Q6arrT4d',
#    'day': 2,
#    'sentiment_score': -0.9102,
#    'parent': '3912',
#    'deaths': 5.0,
#    'cases': 122.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.0009520093640265314,
# ...
#    'day': 31,
#    'sentiment_score': 0.9118,
#    'parent': '0607',
#    'deaths': 7.0,
#    'cases': 224.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00022404929084398568,
#    'deaths_per_capita': 7.001540338874552e-06},
#   {'case_id': 1033,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6025,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 11.0,
#    'text': 'the valley now has 33 cases thats what happens when you choose to party and not social distance just stay home',
#    'day': 31,
#    'sentiment_score': 0.4019,
#    'parent': '0651',
#    'deaths': 0.0,
#    'cases': 33.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00033249370277078086,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1034,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 34031,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'The faster yah go tf in the house and stay their the faster we could come out this aint no joke STAY HOME',
#    'day': 31,
#    'sentiment_score': 0.1673,
#    'parent': '3409',
#    'deaths': 1.0,
#    'cases': 1294.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.003976399729580235,
#    'deaths_per_capita': 3.072951877573597e-06},
#   {'case_id': 1035,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6077,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 1.0,
#    'text': 'Stay the fuck home or were all gonna die of COVID-19 https://t.co/nOfs5xSLoD',
#    'day': 31,
#    'sentiment_score': -0.8126,
#    'parent': '0609',
#    'deaths': 6.0,
#    'cases': 136.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00031387391961596605,
#    'deaths_per_capita': 1.3847378806586737e-05},
#   {'case_id': 1041,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 36005,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "Nicely done guy's. Because we all have to thanks all those medical staff. Who are putting their life on the front line. To save us all. From this deadly disease coronavirus. And you guy's keep stay home so we can keep saving lives. God bless America our home sweet home.  https://t.co/4WyvDVghOc",
#    'day': 31,
#    'sentiment_score': 0.9423,
#    'parent': '3615',
#    'deaths': 465.0,
#    'cases': 7766.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.009350486728593874,
#    'deaths_per_capita': 0.0005598733361828679},
#   {'case_id': 1042,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24031,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 1,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Stuck at home? No. SAFE at home. Thank you @govlarryhogan for taking COVID-19 so seriously.    #maryland #marylandstrong #wereallinthistogether #saferathome #safeathome #stayhome #staysafe #stayhealthy @ https://t.co/JlbfIrccAZ',
#    'day': 31,
#    'sentiment_score': 0.4389,
#    'parent': '2403',
#    'deaths': 1.0,
#    'cases': 388.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0006048041401025673,
#    'deaths_per_capita': 1.5587735569653796e-06},
#   {'case_id': 1043,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 24510,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Maryland has responded early to #COVID19 to #FlattenTheCurve &amp; we now have Stay at Home order. This has been painful, but we hope acting early &amp; strong will pay dividends in lives saved &amp; faster economic recovery. @GovLarryHogan @UMMC https://t.co/OGOzjw1iRB',
#    'day': 31,
#    'sentiment_score': 0.8873,
#    'parent': '2403',
#    'deaths': 2.0,
#    'cases': 187.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0004045911357760253,
#    'deaths_per_capita': 4.327177922738238e-06},
#   {'case_id': 1052,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 25009,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Just stay inside everyone.  Italy is recovering we will too https://t.co/rZGsqRs2RJ',
#    'day': 31,
#    'sentiment_score': 0.0,
#    'parent': '2506',
#    'deaths': 12.0,
#    'cases': 1238.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.002253572403749886,
#    'deaths_per_capita': 2.184399745153363e-05},
#   {'case_id': 1057,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6037,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'These elderly people are just asking to get sick huh STAY HOME',
#    'day': 31,
#    'sentiment_score': -0.5106,
#    'parent': '0640',
#    'deaths': 54.0,
#    'cases': 3019.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0004930195035837406,
#    'deaths_per_capita': 8.818500560954619e-06},
#   {'case_id': 1058,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 48439,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'This is how we do it in Texas !  Stay at home and stay safe yall !#COVID19  #CoronavirusUSA  #essentialservices #StayAtHome https://t.co/yyWTvMEKhu',
#    'day': 31,
#    'sentiment_score': 0.5399,
#    'parent': '4833',
#    'deaths': 1.0,
#    'cases': 273.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00021956810230425866,
#    'deaths_per_capita': 8.042787630192625e-07},
#   {'case_id': 1060,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 36061,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'IF YALL NIGGAS WOULD JUST STAY YALL ASSES INSIDE THEN YOU WONT NEED A REMEDY https://t.co/pqchPSOSqP',
#    'day': 31,
#    'sentiment_score': -0.4824,
#    'parent': '3613',
#    'deaths': 292.0,
#    'cases': 6876.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.005901816636840005,
#    'deaths_per_capita': 0.00025062979318750454},
#   {'case_id': 1062,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 37135,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 1,
#    'retweet_count': 3.0,
#    'text': 'My best friend may be dying. STAY THE FUCK AT HOME.',
#    'day': 31,
#    'sentiment_score': 0.4883,
#    'parent': '3704',
#    'deaths': 0.0,
#    'cases': 37.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00036490951230336803,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1065,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 48439,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Maybe its us essential workers that are out there still spreading the virus Let us stay home!!!',
#    'day': 31,
#    'sentiment_score': 0.0,
#    'parent': '4833',
#    'deaths': 1.0,
#    'cases': 273.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00021956810230425866,
#    'deaths_per_capita': 8.042787630192625e-07},
#   {'case_id': 1067,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 1073,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 1,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 2.0,
#    'text': "Noah's family was on 'Lockdown' for 40 days, 40 nights and God protected them. God will do the same for you. Have Faith.@curtispatmon @jkittkat @profstan72 @BamaT61 @cynthia_rehberg @dixielandlady @jade78052492",
#    'day': 31,
#    'sentiment_score': 0.7269,
#    'parent': '0106',
#    'deaths': 0.0,
#    'cases': 286.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0005824669307454965,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1068,
#    'Authority': 1,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12053,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 1.0,
#    'text': "@GovRonDeSantis you said some beaches here in fla are still opened, people still not doing what they are supposed to be doing, so if the president says another 30 days stay at home, then it's your responsibility as governor to have the people of fla to follow the president rules.",
#    'day': 31,
#    'sentiment_score': 0.0,
#    'parent': '1211',
#    'deaths': 0.0,
#    'cases': 24.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00017169838317355844,
#    'deaths_per_capita': 0.0},
#   {'case_id': 1069,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 45063,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'SC just got an alert for all non essential businesses to close down stay home for ur safety 4 the coronavirus',
#    'day': 31,
#    'sentiment_score': 0.6124,
#    'parent': '4502',
#    'deaths': 1.0,
#    'cases': 54.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.00026453082518921304,
#    'deaths_per_capita': 4.898718984985426e-06},
#   {'case_id': 1072,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 6077,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "@LindseyGrahamSC No. You need to resign now for all the damage you have personally done to this country. Why isn't SC under a statewide stay-at-home order? You are not saving lives. #coronavirus",
#    'day': 31,
#    'sentiment_score': -0.6808,
#    'parent': '0609',
#    'deaths': 6.0,
#    'cases': 136.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.00031387391961596605,
#    'deaths_per_capita': 1.3847378806586737e-05},
#   {'case_id': 1075,
#    'Authority': 1,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 11001,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Listen to King Larry.\n\nStay. The. Fuck. Home. https://t.co/wq3OXaN1DX',
#    'day': 31,
#    'sentiment_score': -0.5423,
#    'parent': '1198',
#    'deaths': 9.0,
#    'cases': 495.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0010018417697180676,
#    'deaths_per_capita': 1.8215304903964863e-05},
#   {'case_id': 1078,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 12095,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': "Got furloughed today. Not the worst thing in the world. I'm happy to stay home and safe, but it sucks it has come to this.",
#    'day': 31,
#    'sentiment_score': 0.2953,
#    'parent': '1210',
#    'deaths': 4.0,
#    'cases': 373.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0004364589488711159,
#    'deaths_per_capita': 4.680524920869876e-06},
#   {'case_id': 1079,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 0,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 48201,
#    'Harm': 1,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Stay home or die! #coronavirus #COVID19 #SixFeetMF https://t.co/MNnbBV5VTp',
#    'day': 31,
#    'sentiment_score': -0.636,
#    'parent': '4829',
#    'deaths': 20.0,
#    'cases': 680.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.0002673586537705434,
#    'deaths_per_capita': 7.863489816780688e-06},
#   {'case_id': 3673,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 27053,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 29.0,
#    'text': 'STAY HOME. Take care of your neighbors. This is happening and we need YOU PERSONALLY to stay safe. https://t.co/3K79uYuX3x',
#    'day': 31,
#    'sentiment_score': 0.7269,
#    'parent': '2705',
#    'deaths': 613.0,
#    'cases': 8393.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.009698965736407234,
#    'deaths_per_capita': 0.000708383890911192},
#   {'case_id': 3703,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 41033,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': '@Sabrinanichol Please stay home and stay safe',
#    'day': 31,
#    'sentiment_score': 0.6369,
#    'parent': '4104',
#    'deaths': 1.0,
#    'cases': 23.0,
#    'is_blue': 0,
#    'cases_per_capita': 0.000347983962478251,
#    'deaths_per_capita': 1.5129737499054392e-05},
#   {'case_id': 3711,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 27053,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'Just a friendly reminder that were in the midst of a PANDEMIC.  \nStay Safe - Stay Home #100,000\n@WCCO @StarTribune @PioneerPress \n@MPRnews @NPR @citypages @mspmag @GovTimWalz @MayorCarter @MayorFrey',
#    'day': 31,
#    'sentiment_score': 0.7269,
#    'parent': '2705',
#    'deaths': 613.0,
#    'cases': 8393.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.009698965736407234,
#    'deaths_per_capita': 0.000708383890911192},
#   {'case_id': 3741,
#    'Authority': 0,
#    'Betrayal': 0,
#    'Care': 1,
#    'Degradation': 0,
#    'Fairness': 0,
#    'Freedom': 0,
#    'GEOID': 32003,
#    'Harm': 0,
#    'Injustice': 0,
#    'Loyalty': 0,
#    'Oppression': 0,
#    'Purity': 0,
#    'Subversion': 0,
#    'for_sah': 1,
#    'is_vivid': 0,
#    'retweet_count': 0.0,
#    'text': 'For many reasons right now, please be safe and stay at home.\n\n#SafeAtHome #SafetyFirst #SafeStreetsSaveLives #PhysicalDistancing #prioritizeyou #besafe #ordertakeout #callafriend #buyrestaurantgiftcards #registertovote #Census2020',
#    'day': 31,
#    'sentiment_score': 0.6369,
#    'parent': '3201',
#    'deaths': 343.0,
#    'cases': 6657.0,
#    'is_blue': 1,
#    'cases_per_capita': 0.004925219089755589,
#    'deaths_per_capita': 0.00025377048937752245}]}

# %%
            
df = data.filter_geolocated(data.augmented_tweet_df).set_index('case_id')
tc = TweetClusterer(['is_blue','cvap'])
tc.add_clusters(df,data.demographic_df)
tc.tweets_in_cluster(1003)

# %%
data.load_frameview_dict()
# Out:
# {'Authority': {'against_sah_rt_quantiles': [5, 1, 0, 0, 0, 0, 0],
#   'for_sah': 131,
#   'for_sah_rt_quantiles': [105, 13, 2, 3, 5, 1, 2],
#   'high_retweets': 0,
#   'is_blue': 101,
#   'negative_sentiment': 48,
#   'positive_sentiment': 49,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 137,
#   'vivid': 14},
#  'Betrayal': {'against_sah_rt_quantiles': [4, 0, 0, 0, 0, 0, 0],
#   'for_sah': 42,
#   'for_sah_rt_quantiles': [30, 6, 0, 3, 0, 2, 1],
#   'high_retweets': 0,
#   'is_blue': 37,
#   'negative_sentiment': 29,
#   'positive_sentiment': 10,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 46,
#   'vivid': 6},
#  'Care': {'against_sah_rt_quantiles': [17, 3, 0, 0, 0, 0, 1],
#   'for_sah': 781,
#   'for_sah_rt_quantiles': [609, 86, 27, 22, 20, 6, 11],
#   'high_retweets': 2,
#   'is_blue': 576,
#   'negative_sentiment': 192,
#   'positive_sentiment': 475,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 802,
#   'vivid': 67},
#  'Degradation': {'against_sah_rt_quantiles': [1, 0, 0, 0, 0, 0, 0],
#   'for_sah': 5,
#   'for_sah_rt_quantiles': [4, 0, 0, 0, 0, 0, 1],
#   'high_retweets': 0,
#   'is_blue': 4,
#   'negative_sentiment': 6,
#   'positive_sentiment': 0,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 6,
#   'vivid': 1},
#  'Fairness': {'against_sah_rt_quantiles': [2, 0, 0, 0, 0, 0, 0],
#   'for_sah': 15,
#   'for_sah_rt_quantiles': [12, 3, 0, 0, 0, 0, 0],
#   'high_retweets': 0,
#   'is_blue': 12,
#   'negative_sentiment': 8,
#   'positive_sentiment': 4,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 17,
#   'vivid': 1},
#  'Freedom': {'against_sah_rt_quantiles': [58, 7, 2, 1, 0, 0, 0],
#   'for_sah': 18,
#   'for_sah_rt_quantiles': [18, 0, 0, 0, 0, 0, 0],
#   'high_retweets': 0,
#   'is_blue': 51,
#   'negative_sentiment': 29,
#   'positive_sentiment': 37,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 86,
#   'vivid': 1},
#  'Harm': {'against_sah_rt_quantiles': [61, 8, 2, 1, 0, 0, 2],
#   'for_sah': 339,
#   'for_sah_rt_quantiles': [254, 46, 14, 12, 5, 6, 2],
#   'high_retweets': 1,
#   'is_blue': 284,
#   'negative_sentiment': 257,
#   'positive_sentiment': 83,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 413,
#   'vivid': 45},
#  'Injustice': {'against_sah_rt_quantiles': [9, 1, 0, 0, 0, 0, 0],
#   'for_sah': 15,
#   'for_sah_rt_quantiles': [10, 2, 2, 0, 0, 1, 0],
#   'high_retweets': 0,
#   'is_blue': 19,
#   'negative_sentiment': 19,
#   'positive_sentiment': 3,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 25,
#   'vivid': 6},
#  'Loyalty': {'against_sah_rt_quantiles': [7, 1, 1, 0, 0, 0, 1],
#   'for_sah': 165,
#   'for_sah_rt_quantiles': [130, 10, 7, 7, 8, 1, 2],
#   'high_retweets': 1,
#   'is_blue': 138,
#   'negative_sentiment': 31,
#   'positive_sentiment': 104,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 175,
#   'vivid': 5},
#  'Oppression': {'against_sah_rt_quantiles': [38, 3, 0, 0, 1, 0, 0],
#   'for_sah': 3,
#   'for_sah_rt_quantiles': [3, 0, 0, 0, 0, 0, 0],
#   'high_retweets': 0,
#   'is_blue': 30,
#   'negative_sentiment': 25,
#   'positive_sentiment': 10,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 45,
#   'vivid': 2},
#  'Purity': {'against_sah_rt_quantiles': [1, 1, 0, 0, 0, 0, 0],
#   'for_sah': 32,
#   'for_sah_rt_quantiles': [31, 0, 1, 0, 0, 0, 0],
#   'high_retweets': 0,
#   'is_blue': 22,
#   'negative_sentiment': 6,
#   'positive_sentiment': 23,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 34,
#   'vivid': 1},
#  'Subversion': {'against_sah_rt_quantiles': [25, 2, 0, 0, 0, 0, 0],
#   'for_sah': 23,
#   'for_sah_rt_quantiles': [18, 3, 1, 0, 0, 1, 0],
#   'high_retweets': 0,
#   'is_blue': 30,
#   'negative_sentiment': 28,
#   'positive_sentiment': 11,
#   'quantile_bins': [0, 1, 2, 3, 5, 10, 22],
#   'total_tweets': 50,
#   'vivid': 6}}
